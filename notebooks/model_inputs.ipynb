# %% [markdown]
# ### Surface

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Load the dataset
ds = xr.open_dataset('/pfs/lustrep1/scratch/project_462000472/akhtar/climate_modeling/pangu-data/cropped_with_pm2.5_model/surface/surface_200406.nc')
print(ds)

# Extract the first time point
first_time = ds.isel(time=0)

# Set up the plotting figure with a 2x2 grid
fig, axs = plt.subplots(3, 2, figsize=(15, 15), subplot_kw={'projection': ccrs.PlateCarree()})

# Define the variables and their titles, along with color maps
variables = ['u10', 'v10', 't2m', 'msl', 'pm2p5']
titles = ['U-Component at 10m (u10)', 'V-Component at 10m (v10)', 'Temperature at 2m (t2m)', 'Mean Sea Level Pressure (msl)', 'Particle Matter (pm2.5)']
colormaps = ['seismic', 'seismic', 'coolwarm', 'coolwarm', 'coolwarm']

# Loop over the variables and plot each one
for i, var in enumerate(variables):
    ax = axs[i // 2, i % 2]  # Adjust subplot position
    data = first_time[var]  # No need to slice level, as this is surface data
    
    # Plot the data with the specified colormap
    im = data.plot(ax=ax, cmap=colormaps[i], add_colorbar=False)

    # Add continent lines and labels
    ax.coastlines(resolution='110m', color='black')
    ax.add_feature(cfeature.BORDERS, linestyle=':', color='black')
    ax.set_title(titles[i])


# Removethe last empty subplot
fig.delaxes(axs[2, 1])

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# <xarray.Dataset> Size: 138MB
# Dimensions:    (time: 60, longitude: 305, latitude: 209)
# Coordinates:
#   * time       (time) datetime64[ns] 480B 2004-06-01 ... 2004-06-30T12:00:00
#   * longitude  (longitude) float32 1kB 0.0 0.25 0.5 0.75 ... 75.5 75.75 76.0
#   * latitude   (latitude) float32 836B -7.0 -6.75 -6.5 -6.25 ... 44.5 44.75 45.0
# Data variables:
#     u10        (time, latitude, longitude) float64 31MB ...
#     v10        (time, latitude, longitude) float64 31MB ...
#     t2m        (time, latitude, longitude) float64 31MB ...
#     msl        (time, latitude, longitude) float64 31MB ...
#     pm2p5      (time, latitude, longitude) float32 15MB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.4.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Sat Jan 18 09:51:58 2025: cdo splitmon /pfs/lustrep1/scratc...
#     CDO:          Climate Data Operators version 2.4.4 (https://mpimet.mpg.de...
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ### Upper

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Load the dataset
ds = xr.open_dataset('/pfs/lustrep1/scratch/project_462000472/akhtar/climate_modeling/pangu-data/cropped_with_pm2.5_model/upper/upper_20090716.nc')
print(ds)

# Extract the first time point
first_time = ds.isel(time=0)

# Set up the plotting figure
fig, axs = plt.subplots(3, 2, figsize=(15, 15), subplot_kw={'projection': ccrs.PlateCarree()})

# Define the variables and their titles, along with color maps
variables = ['z', 'q', 't', 'u', 'v']
titles = ['Height (z)', 'Specific Humidity (q)', 'Temperature (t)', 'U-Component (u)', 'V-Component (v)']
colormaps = ['coolwarm', 'coolwarm', 'coolwarm', 'seismic', 'seismic']

# Loop over the variables and plot each one
for i, var in enumerate(variables):
    ax = axs[i // 2, i % 2]  # Adjust subplot position
    data = first_time[var].isel(level=0)  # Plot at the first level
    
    # Plot the data with the specified colormap
    im = data.plot(ax=ax, cmap=colormaps[i], add_colorbar=False)

    # Add continent lines and labels
    ax.coastlines(resolution='110m', color='black')
    ax.add_feature(cfeature.BORDERS, linestyle=':', color='black')
    ax.set_title(titles[i])

# Remove the last empty subplot
fig.delaxes(axs[2, 1])

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
# Out:
# <xarray.Dataset> Size: 66MB
# Dimensions:    (time: 2, longitude: 305, latitude: 209, level: 13)
# Coordinates:
#   * time       (time) datetime64[ns] 16B 2009-07-16 2009-07-16T12:00:00
#   * longitude  (longitude) float32 1kB 0.0 0.25 0.5 0.75 ... 75.5 75.75 76.0
#   * latitude   (latitude) float32 836B 45.0 44.75 44.5 44.25 ... -6.5 -6.75 -7.0
#   * level      (level) int32 52B 50 100 150 200 250 300 ... 600 700 850 925 1000
# Data variables:
#     z          (time, level, latitude, longitude) float64 13MB ...
#     q          (time, level, latitude, longitude) float64 13MB ...
#     t          (time, level, latitude, longitude) float64 13MB ...
#     u          (time, level, latitude, longitude) float64 13MB ...
#     v          (time, level, latitude, longitude) float64 13MB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.4.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Fri Jan 17 20:19:11 2025: cdo sellonlatbox,-0.01,76.01,-7.0...
#     CDO:          Climate Data Operators version 2.4.4 (https://mpimet.mpg.de...
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /pfs/lustrep1/scratch/project_462000472/akhtar/envs/pangu/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
