# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Full_finetune_05201_inference/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl     3.392762e+02
# u10     2.460175e+00
# v10     2.486741e+00
# t2m     2.226954e+00
# pm1     1.014137e-08
# pm25    1.742076e-08
# pm10    2.712525e-08
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Finetune_fromscratch_05201_inference/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl     5.571242e+02
# u10     3.577173e+00
# v10     3.845262e+00
# t2m     3.567543e+00
# pm1     1.059203e-08
# pm25    1.884673e-08
# pm10    2.973426e-08
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_inference_on_mena/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl    1072.010332
# u10       6.245962
# v10       6.103192
# t2m       5.003529
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_inference_on_mena/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl    1105.111043
# u10       6.259128
# v10       5.918144
# t2m       5.596706
# dtype: float64

# %%
import pickle

input_surface = pickle.load(open('input_surface.pkl', 'rb'))

# %%
input_surface.shape
# Out:
# torch.Size([1, 7, 721, 1440])

# %%
mean_input_surface = input_surface.mean(axis=(-1, -2))  # Mean across the last two dimensions (lat, lon)
print(mean_input_surface)
# Out:
# tensor([[-0.0845, -0.0051, -0.0859, -0.0557,  0.0314,  4.0900,  4.3316]],
#        device='cuda:0')

# %%
std= input_surface.std(axis=(-1, -2))  # Standard deviation across the last two dimensions (lat, lon)
print(std)
# Out:
# tensor([[ 1.0634,  0.9472,  1.0165,  0.9036, 10.9984,  9.8938,  9.3694]],
#        device='cuda:0')

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/original/pangu-pytorch/result/reproduce_mask0/24/test/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl    995.194327
# u10      6.644251
# v10      5.794114
# t2m      5.622214
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Full_finetune_05201_inference/csv/rmse_upper_z.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# 1000    143.366992
# 925     134.602268
# 850     132.562390
# 700     130.964334
# 600     147.828579
# 500     154.348219
# 400     181.093023
# 300     191.197300
# 250     197.071390
# 200     179.370445
# 150     202.902999
# 100     176.142109
# 50      201.689672
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/original/pangu-pytorch/result/May_29_given_data/24/test/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
print("Mean RMSE across levels:", avg_rmses.mean())
# Out:
# msl    59.613091
# u10     0.926425
# v10     0.945511
# t2m     0.702776
# dtype: float64
# Mean RMSE across levels: 15.546950866681033

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/original/pangu-pytorch/result/May_29_with_pm/24/test/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
print("Mean RMSE across levels:", avg_rmses.mean())
# Out:
# msl    995.194327
# u10      6.644251
# v10      5.794114
# t2m      5.622214
# dtype: float64
# Mean RMSE across levels: 253.3137266310345

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/original/pangu-pytorch/result/May_30_downloaded_data/24/test/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
print("Mean RMSE across levels:", avg_rmses.mean())
# Out:
# msl    59.613091
# u10     0.926425
# v10     0.945511
# t2m     0.702776
# dtype: float64
# Mean RMSE across levels: 15.546950866681033

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/original/pangu-pytorch/result/May_30_merged_test2/24/test/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
print("Mean RMSE across levels:", avg_rmses.mean())
# Out:
# msl    83.562344
# u10     1.069492
# v10     1.065469
# t2m     0.919770
# dtype: float64
# Mean RMSE across levels: 21.654268936336205
