# %% [markdown]
# # lora_full_finetune

# %% [markdown]
# ### 1. Inference - MENA

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/lora_full_finetune/csv5_mena'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_upper_u.csv:
# Mean across vertical levels: 0.974127
#
# acc_surface.csv:
# msl  : 0.467887
# u10  : 0.984789
# v10  : 0.952317
# t2m  : 0.999894
# pm1  : 1.000 × 10^0
# pm25 : 10.000 × 10^-1
# pm10 : 10.000 × 10^-1
#
# rmse_upper_v.csv:
# Mean across vertical levels: 1.805851
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000404
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.980748
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.972992
#
# rmse_upper_z.csv:
# Mean across vertical levels: 43.262134
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.583898
#
# rmse_upper_u.csv:
# Mean across vertical levels: 1.900352
#
# rmse_surface.csv:
# msl  : 29.683073
# u10  : 0.871156
# v10  : 0.959248
# t2m  : 0.316458
# pm1  : 1.644 × 10^-9
# pm25 : 2.828 × 10^-9
# pm10 : 4.386 × 10^-9
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.613280
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.945775

# %% [markdown]
# ## 2. Inference - World

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/lora_full_finetune/csv5_world'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000307
#
# rmse_upper_v.csv:
# Mean across vertical levels: 1.868704
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.957740
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.972170
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.986394
#
# rmse_upper_z.csv:
# Mean across vertical levels: 73.907173
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.661314
#
# acc_surface.csv:
# msl  : 0.998056
# u10  : 0.983827
# v10  : 0.974960
# t2m  : 0.998834
# pm1  : 10.000 × 10^-1
# pm25 : 10.000 × 10^-1
# pm10 : 10.000 × 10^-1
#
# rmse_upper_u.csv:
# Mean across vertical levels: 1.835037
#
# rmse_surface.csv:
# msl  : 75.941734
# u10  : 0.997253
# v10  : 1.046803
# t2m  : 0.869375
# pm1  : 1.010 × 10^-8
# pm25 : 1.666 × 10^-8
# pm10 : 2.476 × 10^-8
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.996433
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.999589
