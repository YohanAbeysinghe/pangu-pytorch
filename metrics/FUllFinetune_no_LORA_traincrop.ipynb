# %% [markdown]
# # lora_full_finetune

# %% [markdown]
# ### 1. Inference - MENA

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/MENA_finetune_normalized_0602_2/csv5_MENA'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                if np.isnan(val):
                    print(f"{var:5s}: NaN")
                    continue
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_surface.csv:
# msl  : 0.531560
# u10  : 0.660080
# v10  : 0.673317
# t2m  : 0.832806
# pm1  : -2.829 × 10^-2
# pm25 : 6.303 × 10^-1
# pm10 : NaN
#
# rmse_upper_t.csv:
# Mean across vertical levels: 6.483222
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.918453
#
# rmse_upper_z.csv:
# Mean across vertical levels: 1700.557486
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.810347
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.886497
#
# rmse_upper_u.csv:
# Mean across vertical levels: 3.984152
#
# rmse_surface.csv:
# msl  : 1352.662690
# u10  : 4.144393
# v10  : 2.801660
# t2m  : 12.181396
# pm1  : 5.929 × 10^3
# pm25 : 1.483 × 10^-1
# pm10 : 0.000 × 10^0
#
# rmse_upper_v.csv:
# Mean across vertical levels: 3.496465
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000913
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.817546
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.509552

# %% [markdown]
# ## 2. Inference - World

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/MENA_finetune_normalized_0602_2/csv5_world'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# rmse_surface.csv:
# msl  : 35172.713795
# u10  : 130.461165
# v10  : 23.397543
# t2m  : 54.557088
# pm1  : 3.407 × 10^7
# pm25 : 2.903 × 10^4
# pm10 : 7.490 × 10^6
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.100674
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.944553
#
# rmse_upper_u.csv:
# Mean across vertical levels: 62.078467
#
# rmse_upper_t.csv:
# Mean across vertical levels: 64.733610
#
# rmse_upper_z.csv:
# Mean across vertical levels: 14270.210208
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.998502
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.999431
#
# acc_surface.csv:
# msl  : 0.999578
# u10  : 0.037042
# v10  : 0.148838
# t2m  : 0.998229
# pm1  : -2.210 × 10^-1
# pm25 : -2.331 × 10^-1
# pm10 : -2.343 × 10^-1
#
# acc_upper_u.csv:
# Mean across vertical levels: -0.643976
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.002560
#
# rmse_upper_v.csv:
# Mean across vertical levels: 22.244981
