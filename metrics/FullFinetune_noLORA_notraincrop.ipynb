# %% [markdown]
# # lora_full_finetune

# %% [markdown]
# ### 1. Inference - MENA

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Full_finetune_normalized_0602_1/csv5_MENA'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                if np.isnan(val):
                    print(f"{var:5s}: NaN")
                    continue
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_surface.csv:
# msl  : 0.262982
# u10  : 0.848186
# v10  : 0.747919
# t2m  : 0.846294
# pm1  : 10.000 × 10^-1
# pm25 : 10.000 × 10^-1
# pm10 : 2.061 × 10^-2
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.806539
#
# rmse_surface.csv:
# msl  : 2039.138160
# u10  : 2.842089
# v10  : 2.429345
# t2m  : 11.579881
# pm1  : 1.538 × 10^-6
# pm25 : 9.194 × 10^-4
# pm10 : 3.127 × 10^0
#
# rmse_upper_u.csv:
# Mean across vertical levels: 6.052686
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.806074
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.823915
#
# rmse_upper_t.csv:
# Mean across vertical levels: 6.820171
#
# rmse_upper_z.csv:
# Mean across vertical levels: 1961.756241
#
# rmse_upper_v.csv:
# Mean across vertical levels: 3.953584
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000914
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.821365
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.523371

# %% [markdown]
# ## 2. Inference - World

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Full_finetune_normalized_0602_1/csv_world'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_upper_z.csv:
# Mean across vertical levels: 0.998123
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.994778
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.988748
#
# rmse_upper_z.csv:
# Mean across vertical levels: 133.029630
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.975177
#
# acc_surface.csv:
# msl  : 0.991702
# u10  : 0.963122
# v10  : 0.942470
# t2m  : 0.997746
# pm1  : 10.000 × 10^-1
# pm25 : 10.000 × 10^-1
# pm10 : 10.000 × 10^-1
#
# rmse_surface.csv:
# msl  : 150.032823
# u10  : 1.467262
# v10  : 1.526566
# t2m  : 1.211503
# pm1  : 1.021 × 10^-8
# pm25 : 1.738 × 10^-8
# pm10 : 2.630 × 10^-8
#
# rmse_upper_u.csv:
# Mean across vertical levels: 2.681526
#
# rmse_upper_v.csv:
# Mean across vertical levels: 2.723593
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000397
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.942150
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.935191
