# %% [markdown]
# # proper_crop_mena_train_lora

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/proper_crop_mena_train_lora/csv5_'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# rmse_upper_t.csv:
# Mean across vertical levels: 0.299088
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.924216
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.891189
#
# rmse_upper_z.csv:
# Mean across vertical levels: 43.703127
#
# rmse_surface.csv:
# msl  : 42.234309
# u10  : 0.432478
# v10  : 0.479241
# t2m  : 0.227909
# pm1  : 9.090 × 10^-10
# pm25 : 1.455 × 10^-9
# pm10 : 2.317 × 10^-9
#
# rmse_upper_u.csv:
# Mean across vertical levels: 0.895284
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.996708
#
# rmse_upper_v.csv:
# Mean across vertical levels: 0.921889
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.988411
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000132
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.961690
#
# acc_surface.csv:
# msl  : 0.976885
# u10  : 0.963195
# v10  : 0.921893
# t2m  : 0.999098
# pm1  : 10.000 × 10^-1
# pm25 : 10.000 × 10^-1
# pm10 : 10.000 × 10^-1

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/proper_crop_mena_train_lora/csv5_1'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_upper_q.csv:
# Mean across vertical levels: 0.932459
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.667521
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000441
#
# rmse_upper_v.csv:
# Mean across vertical levels: 2.024889
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.978032
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.988584
#
# rmse_surface.csv:
# msl  : 51.982626
# u10  : 0.917515
# v10  : 0.993868
# t2m  : 0.353816
# pm1  : 1.965 × 10^-9
# pm25 : 3.122 × 10^-9
# pm10 : 4.672 × 10^-9
#
# rmse_upper_u.csv:
# Mean across vertical levels: 2.184828
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.969626
#
# acc_surface.csv:
# msl  : 0.742163
# u10  : 0.985000
# v10  : 0.956960
# t2m  : 0.999923
# pm1  : 10.000 × 10^-1
# pm25 : 10.000 × 10^-1
# pm10 : 10.000 × 10^-1
#
# rmse_upper_z.csv:
# Mean across vertical levels: 70.340506
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.638274
