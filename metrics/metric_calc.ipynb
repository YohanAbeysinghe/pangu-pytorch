# %% [markdown]
# # Original Pangu

# %% [markdown]
# ### 1. Inference - World

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_Inference_2019_0602/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl    58.431464
# u10     0.913679
# v10     0.943195
# t2m     0.724701
# dtype: float64

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_Inference_2019_0602/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl    60.376262
# u10     0.926150
# v10     0.952353
# t2m     0.735746
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv('/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Full_finetune_normalized_0602_1/csv/rmse_surface.csv')
avg_rmses = df.iloc[:, 1:].mean()  # Skip the first column (time/index), compute mean for the rest
print(avg_rmses)
# Out:
# msl     1.511450e+02
# u10     1.486363e+00
# v10     1.535981e+00
# t2m     1.222715e+00
# pm1     1.021120e-08
# pm25    1.738416e-08
# pm10    2.631116e-08
# dtype: float64
