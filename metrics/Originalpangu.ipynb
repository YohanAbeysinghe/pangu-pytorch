# %% [markdown]
# # Original Pangu

# %% [markdown]
# ### 1. Inference - World

# %% [markdown]
# * Something is worng with 2019 Jan 18th. Without this hard time point, results are much better as shown above.
#
# * Jan 17th upper data is missing for one day. TODO - Re-download.

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_Inference_world/csv'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# rmse_upper_v.csv:
# Mean across vertical levels: 1.717588
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000293
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.997970
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.999720
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.989876
#
# acc_surface.csv:
# msl  : 0.998633
# u10  : 0.985796
# v10  : 0.978391
# t2m  : 0.999185
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.976534
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.960284
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.596568
#
# rmse_upper_z.csv:
# Mean across vertical levels: 50.036799
#
# rmse_upper_u.csv:
# Mean across vertical levels: 1.701307
#
# rmse_surface.csv:
# msl  : 58.431464
# u10  : 0.913679
# v10  : 0.943195
# t2m  : 0.724701

# %% [markdown]
# ## Inference MENA

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_Inference_MENA/csv5_'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# acc_upper_q.csv:
# Mean across vertical levels: 0.947798
#
# rmse_upper_v.csv:
# Mean across vertical levels: 1.760153
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.613270
#
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000391
#
# rmse_surface.csv:
# msl  : 29.324361
# u10  : 0.801865
# v10  : 0.913834
# t2m  : 0.273829
#
# acc_surface.csv:
# msl  : 0.460376
# u10  : 0.988079
# v10  : 0.957367
# t2m  : 0.999910
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.973943
#
# rmse_upper_u.csv:
# Mean across vertical levels: 1.840147
#
# rmse_upper_t.csv:
# Mean across vertical levels: 0.565388
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.965545
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.979679
#
# rmse_upper_z.csv:
# Mean across vertical levels: 34.411699

# %%
import pandas as pd
import numpy as np
import os

# Directory path
csv_dir = '/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/results/Original_Pangu_Inference_MENA_721/csv5_'

# List all .csv files
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Loop through each file
for csv_file in csv_files:
    file_path = os.path.join(csv_dir, csv_file)
    df = pd.read_csv(file_path)
    avg = df.iloc[:, 1:].mean()

    print(f"\n{csv_file}:")

    if 'upper' in csv_file:
        overall_mean = avg.mean()
        print(f"Mean across vertical levels: {overall_mean:.6f}")
    else:
        for var, val in avg.items():
            if var.lower() in ['pm1', 'pm25', 'pm10']:
                exponent = int(np.floor(np.log10(abs(val)))) if val != 0 else 0
                coeff = val / (10**exponent) if val != 0 else 0
                print(f"{var:5s}: {coeff:.3f} × 10^{exponent}")
            else:
                print(f"{var:5s}: {val:.6f}")
# Out:
# rmse_upper_q.csv:
# Mean across vertical levels: 0.000675
#
# rmse_upper_v.csv:
# Mean across vertical levels: 4.730798
#
# acc_upper_q.csv:
# Mean across vertical levels: 0.917829
#
# acc_upper_v.csv:
# Mean across vertical levels: 0.920425
#
# rmse_upper_t.csv:
# Mean across vertical levels: 2.685144
#
# acc_surface.csv:
# msl  : 0.988975
# u10  : 0.962165
# v10  : 0.953496
# t2m  : 0.999048
#
# rmse_upper_z.csv:
# Mean across vertical levels: 119.679880
#
# acc_upper_u.csv:
# Mean across vertical levels: 0.933512
#
# acc_upper_z.csv:
# Mean across vertical levels: 0.998195
#
# rmse_surface.csv:
# msl  : 124.163518
# u10  : 2.166668
# v10  : 2.163229
# t2m  : 1.182848
#
# acc_upper_t.csv:
# Mean across vertical levels: 0.962082
#
# rmse_upper_u.csv:
# Mean across vertical levels: 6.422203
