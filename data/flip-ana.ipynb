# %%
import xarray as xr
import numpy as np

# %% [markdown]
# ## Merged Data

# %% [markdown]
# U10

# %%
input_surface_dataset = xr.open_dataset("/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/surface/surface_201901.nc")  # 201501
first_timestep = input_surface_dataset["u10"].isel(time=0).values
print(first_timestep.shape)
print(first_timestep)
# Out:
# (721, 1440)
# [[-0.08111005 -0.08111005 -0.08111005 ... -0.08111005 -0.08111005
#   -0.08111005]
#  [ 1.40839903  1.38857667  1.3687543  ...  1.46503436  1.44521199
#    1.42633355]
#  [ 1.42161394  1.39518412  1.36214685 ...  1.51883792  1.48108103
#    1.44898768]
#  ...
#  [-4.06823704 -4.07012488 -4.0710688  ... -4.05502213 -4.05974174
#   -4.06446135]
#  [-3.85774241 -3.85774241 -3.85774241 ... -3.84830319 -3.85207888
#   -3.85491064]
#  [ 0.18696382  0.18696382  0.18696382 ...  0.18696382  0.18696382
#    0.18696382]]

# %%
first_timestep[300]
# Out:
# array([-4.27212421, -4.00876995, -3.54530419, ..., -4.2928905 ,
#        -4.3740678 , -4.2758999 ], shape=(1440,))

# %% [markdown]
# PM2.5

# %%
pm2p5 = input_surface_dataset["pm2p5"].isel(time=0).values
print(pm2p5.shape)
print(pm2p5)
# Out:
# (721, 1440)
# [[2.0211864e-10 2.0211864e-10 2.0211864e-10 ... 2.0211864e-10
#   2.0211864e-10 2.0211864e-10]
#  [2.3580510e-10 2.3580510e-10 2.3580510e-10 ... 2.3580510e-10
#   2.3580510e-10 2.3580510e-10]
#  [2.6949151e-10 2.6949151e-10 2.6949151e-10 ... 2.6949151e-10
#   2.6949151e-10 2.6949151e-10]
#  ...
#  [1.0218221e-09 1.0218221e-09 1.0218221e-09 ... 1.0218221e-09
#   1.0218221e-09 1.0218221e-09]
#  [8.3093221e-10 8.3093221e-10 8.3093221e-10 ... 8.3093221e-10
#   8.3093221e-10 8.3093221e-10]
#  [6.4004235e-10 6.4004235e-10 6.4004235e-10 ... 6.4004235e-10
#   6.4004235e-10 6.4004235e-10]]

# %% [markdown]
# ## Original Surface Data

# %%
u10 = xr.open_dataset("/l/users/fahad.khan/akhtar/Pangu/data/pangu_data/surface/surface_201901.nc")  # 201501
u10 = u10["u10"].isel(time=0).values
print(u10.shape)
print(u10)
# Out:
# (721, 1440)
# [[-0.08111005 -0.08111005 -0.08111005 ... -0.08111005 -0.08111005
#   -0.08111005]
#  [ 1.40839903  1.38857667  1.3687543  ...  1.46503436  1.44521199
#    1.42633355]
#  [ 1.42161394  1.39518412  1.36214685 ...  1.51883792  1.48108103
#    1.44898768]
#  ...
#  [-4.06823704 -4.07012488 -4.0710688  ... -4.05502213 -4.05974174
#   -4.06446135]
#  [-3.85774241 -3.85774241 -3.85774241 ... -3.84830319 -3.85207888
#   -3.85491064]
#  [ 0.18696382  0.18696382  0.18696382 ...  0.18696382  0.18696382
#    0.18696382]]

# %%
u10[300]
# Out:
# array([-4.27212421, -4.00876995, -3.54530419, ..., -4.2928905 ,
#        -4.3740678 , -4.2758999 ], shape=(1440,))

# %% [markdown]
# ## Original Downloaded PM

# %%
pm = xr.open_dataset("/l/users/fahad.khan/akhtar/Pangu/data/data_prep/pm-orig/cams_201901.nc")  # 201501
pm1 = pm["pm2p5"].isel(time=0).values
print(pm1.shape)
print(pm1)
# Out:
# (241, 480)
# [[2.02118644e-10 2.02118644e-10 2.02118644e-10 ... 2.02118644e-10
#   2.02118644e-10 2.02118644e-10]
#  [3.03177966e-10 3.03177966e-10 3.03177966e-10 ... 3.03177966e-10
#   3.03177966e-10 3.03177966e-10]
#  [4.04237288e-10 4.04237288e-10 4.37923729e-10 ... 4.04237288e-10
#   4.04237288e-10 4.04237288e-10]
#  ...
#  [1.01059322e-09 1.01059322e-09 1.01059322e-09 ... 1.01059322e-09
#   1.01059322e-09 1.01059322e-09]
#  [1.21271186e-09 1.21271186e-09 1.21271186e-09 ... 1.21271186e-09
#   1.21271186e-09 1.21271186e-09]
#  [6.40042373e-10 6.40042373e-10 6.40042373e-10 ... 6.40042373e-10
#   6.40042373e-10 6.40042373e-10]]

# %% [markdown]
# ## PM After Flipping and Processing

# %%
pm = xr.open_dataset("/l/users/fahad.khan/akhtar/Pangu/data/data_prep/pm-processed-orig/cams_201901_025_renamed_flipped.nc")  # 201501
pm1 = pm["pm2p5"].isel(time=0).values
print(pm1.shape)
print(pm1)
# Out:
# (721, 1440)
# [[2.0211864e-10 2.0211864e-10 2.0211864e-10 ... 2.0211864e-10
#   2.0211864e-10 2.0211864e-10]
#  [2.3580510e-10 2.3580510e-10 2.3580510e-10 ... 2.3580510e-10
#   2.3580510e-10 2.3580510e-10]
#  [2.6949151e-10 2.6949151e-10 2.6949151e-10 ... 2.6949151e-10
#   2.6949151e-10 2.6949151e-10]
#  ...
#  [1.0218221e-09 1.0218221e-09 1.0218221e-09 ... 1.0218221e-09
#   1.0218221e-09 1.0218221e-09]
#  [8.3093221e-10 8.3093221e-10 8.3093221e-10 ... 8.3093221e-10
#   8.3093221e-10 8.3093221e-10]
#  [6.4004235e-10 6.4004235e-10 6.4004235e-10 ... 6.4004235e-10
#   6.4004235e-10 6.4004235e-10]]
